# %% [markdown]
# # Table of Contents

# %%
import os
import random
import time
import json
import warnings 
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import lr_scheduler
from utils import label_accuracy_score, add_hist
import cv2

import numpy as np
import pandas as pd
from tqdm import tqdm

# 전처리를 위한 라이브러리
from pycocotools.coco import COCO
import torchvision
import torchvision.transforms as transforms

#!pip install albumentations==0.4.6
import albumentations as A
from albumentations.pytorch import ToTensorV2

# 시각화를 위한 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from matplotlib.patches import Patch

#!pip install webcolors
import webcolors

plt.rcParams['axes.grid'] = False

print('pytorch version: {}'.format(torch.__version__))
print('GPU 사용 가능 여부: {}'.format(torch.cuda.is_available()))

print(torch.cuda.get_device_name(0))
print(torch.cuda.device_count())

# GPU 사용 가능 여부에 따라 device 정보 저장
device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# pytorch version: 1.13.1+cu117
# GPU 사용 가능 여부: True
# Tesla V100-PCIE-32GB
# 1

# %% [markdown]
# ## 하이퍼파라미터 세팅 및 seed 고정

# %%
batch_size = 16   # Mini-batch size
num_epochs = 100
learning_rate = 0.0001

# %%
# seed 고정
random_seed = 42
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)
random.seed(random_seed)

# %% [markdown]
# ## 학습 데이터 EDA

# %%
# %matplotlib inline

dataset_path  = '/opt/ml/input/data'
anns_file_path = dataset_path + '/' + 'train_all.json'

# Read annotations
with open(anns_file_path, 'r') as f:
    dataset = json.loads(f.read())

categories = dataset['categories']
anns = dataset['annotations']
imgs = dataset['images']
nr_cats = len(categories)
nr_annotations = len(anns)
nr_images = len(imgs)

# Load categories and super categories
cat_names = []
super_cat_names = []
super_cat_ids = {}
super_cat_last_name = ''
nr_super_cats = 0
for cat_it in categories:
    cat_names.append(cat_it['name'])
    super_cat_name = cat_it['supercategory']
    # Adding new supercat
    if super_cat_name != super_cat_last_name:
        super_cat_names.append(super_cat_name)
        super_cat_ids[super_cat_name] = nr_super_cats
        super_cat_last_name = super_cat_name
        nr_super_cats += 1

print('Number of super categories:', nr_super_cats)
print('Number of categories:', nr_cats)
print('Number of annotations:', nr_annotations)
print('Number of images:', nr_images)
# Out:
# Number of super categories: 10
# Number of categories: 10
# Number of annotations: 26240
# Number of images: 3272

# %%
# Count annotations
cat_histogram = np.zeros(nr_cats,dtype=int)
for ann in anns:
    cat_histogram[ann['category_id']-1] += 1

# Convert to DataFrame
df = pd.DataFrame({'Categories': cat_names, 'Number of annotations': cat_histogram})
df = df.sort_values('Number of annotations', 0, False)

# %%
# category labeling 
sorted_temp_df = df.sort_index()

# background = 0 에 해당되는 label 추가 후 기존들을 모두 label + 1 로 설정
sorted_df = pd.DataFrame(["Backgroud"], columns = ["Categories"])
sorted_df = sorted_df.append(sorted_temp_df, ignore_index=True)

# %%
# class (Categories) 에 따른 index 확인 (0~10 : 총 11개)
sorted_df
# Out:
#        Categories  Number of annotations
# 0       Backgroud                    NaN
# 1   General trash                 2782.0
# 2           Paper                 9311.0
# 3      Paper pack                  659.0
# 4           Metal                  562.0
# 5           Glass                  610.0
# 6         Plastic                 3090.0
# 7       Styrofoam                 1343.0
# 8     Plastic bag                 7643.0
# 9         Battery                   63.0
# 10       Clothing                  177.0

# %% [markdown]
# ## COCO(data_dir) 데이터 전처리 함수 정의 (Dataset)

# %%
category_names = list(sorted_df.Categories)

def get_classname(classID, cats):
    for i in range(len(cats)):
        if cats[i]['id']==classID:
            return cats[i]['name']
    return "None"

class CustomDataLoader(Dataset):
    """COCO format"""
    def __init__(self, data_dir, mode = 'train', transform = None):
        super().__init__()
        self.mode = mode
        self.transform = transform
        self.coco = COCO(data_dir)
        
    def __getitem__(self, index: int):
        # dataset이 index되어 list처럼 동작
        image_id = self.coco.getImgIds(imgIds=index)
        image_infos = self.coco.loadImgs(image_id)[0]
        
        # cv2 를 활용하여 image 불러오기
        images = cv2.imread(os.path.join(dataset_path, image_infos['file_name']))
        images = cv2.cvtColor(images, cv2.COLOR_BGR2RGB).astype(np.float32)
        images /= 255.0
        
        if (self.mode in ('train', 'val')):
            ann_ids = self.coco.getAnnIds(imgIds=image_infos['id'])
            anns = self.coco.loadAnns(ann_ids)

            # Load the categories in a variable
            cat_ids = self.coco.getCatIds()
            cats = self.coco.loadCats(cat_ids)

            # masks : size가 (height x width)인 2D
            # 각각의 pixel 값에는 "category id" 할당
            # Background = 0
            masks = np.zeros((image_infos["height"], image_infos["width"]))
            # General trash = 1, ... , Cigarette = 10
            anns = sorted(anns, key=lambda idx : idx['area'], reverse=True)
            for i in range(len(anns)):
                className = get_classname(anns[i]['category_id'], cats)
                pixel_value = category_names.index(className)
                masks[self.coco.annToMask(anns[i]) == 1] = pixel_value
            masks = masks.astype(np.int8)
                        
            # transform -> albumentations 라이브러리 활용
            if self.transform is not None:
                transformed = self.transform(image=images, mask=masks)
                images = transformed["image"]
                masks = transformed["mask"]
            return images, masks, image_infos
        
        if self.mode == 'test':
            # transform -> albumentations 라이브러리 활용
            if self.transform is not None:
                transformed = self.transform(image=images)
                images = transformed["image"]
            return images, image_infos
    
    def __len__(self) -> int:
        # 전체 dataset의 size를 return
        return len(self.coco.getImgIds())

# %% [markdown]
# ## Dataset 정의 및 DataLoader 할당

# %%
# train.json / validation.json / test.json 디렉토리 설정
train_path = dataset_path + '/K-fold_train1.json'
val_path = dataset_path + '/K-fold_val1.json'
test_path = dataset_path + '/test.json'

# collate_fn needs for batch
def collate_fn(batch):
    return tuple(zip(*batch))


import albumentations as A
from albumentations.pytorch import ToTensorV2

train_transform = A.Compose([
                            #A.CropNonEmptyMaskIfExists(256,256,p=1),
                            A.HorizontalFlip(p=0.5),
                            A.OneOf([
                                A.ShiftScaleRotate(p=1),
                                A.RandomRotate90(p=1),
                            ], p=0.3),
                            A.OneOf([
                                A.Blur(blur_limit=3, p=1),
                                A.MotionBlur(blur_limit=3, p=1),
                                A.MedianBlur(blur_limit=3, p=1),
                                A.Sharpen(p=1),
                            ], p=0.2),
                            ToTensorV2()
                            ])
val_transform = A.Compose([
                          ToTensorV2()
                          ])

test_transform = A.Compose([
                           ToTensorV2()
                           ])

# create own Dataset
# train dataset
train_dataset = CustomDataLoader(data_dir=train_path, mode='train', transform=train_transform)

# validation dataset
val_dataset = CustomDataLoader(data_dir=val_path, mode='val', transform=val_transform)

# test dataset
test_dataset = CustomDataLoader(data_dir=test_path, mode='test', transform=test_transform)


# DataLoader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size,
                                           shuffle=True,
                                           num_workers=4,
                                           collate_fn=collate_fn)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset, 
                                         batch_size=batch_size,
                                         shuffle=False,
                                         num_workers=4,
                                         collate_fn=collate_fn)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          num_workers=4,
                                          collate_fn=collate_fn)
# Out:
# loading annotations into memory...
# Done (t=10.14s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=2.28s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %% [markdown]
# ## baseline model
#
# ### `smp.Unet()`

# %%
# jupyter command 에서 library download 하기
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch

# %%
import segmentation_models_pytorch as smp

# %% [markdown]
# ## train, validation, test 함수 정의

# %%
# wandb 시각화용 클래스 딕셔너리
class_labels = dict(sorted_df["Categories"])

# %%
import torch.cuda.amp as amp
scaler = amp.GradScaler(enabled=True)

# %%
import wandb

# %%
sweep_config = {
    'name' : 'HJ_smp_sweep', # sweep name
    'method': 'grid',        # grid, random, bayes
    'metric': {
        'name': 'Val/mIoU',
        'goal': 'maximize'   # 추적할 목표 
        },
    'parameters' : {
        'optimizer': {
                'values': ['AdamW', 'AdamP'] # 'Adam', 
        },
    }
}

# %%
import pprint

pprint.pprint(sweep_config)
# Out:
# {'method': 'grid',
#  'metric': {'goal': 'maximize', 'name': 'Val/mIoU'},
#  'name': 'HJ_smp_sweep',
#  'parameters': {'optimizer': {'values': ['Adam', 'AdamW', 'AdamP']}}}

# %%
sweep_id = wandb.sweep(sweep_config, project="sweep_Unet++effv2") # 프로젝트명
# Out:
# Create sweep with ID: o8rvmjks
# Sweep URL: https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/sweeps/o8rvmjks

# %% [markdown]
# ## FocalTversky_loss 정의

# %%
def softmax_helper(x):
    # copy from: https://github.com/MIC-DKFZ/nnUNet/blob/master/nnunet/utilities/nd_softmax.py
    rpt = [1 for _ in range(len(x.size()))]
    rpt[1] = x.size(1)
    x_max = x.max(1, keepdim=True)[0].repeat(*rpt)
    e_x = torch.exp(x - x_max)
    return e_x / e_x.sum(1, keepdim=True).repeat(*rpt)

# %%
def sum_tensor(inp, axes, keepdim=False):
    # copy from: https://github.com/MIC-DKFZ/nnUNet/blob/master/nnunet/utilities/tensor_utilities.py
    axes = np.unique(axes).astype(int)
    if keepdim:
        for ax in axes:
            inp = inp.sum(int(ax), keepdim=True)
    else:
        for ax in sorted(axes, reverse=True):
            inp = inp.sum(int(ax))
    return inp

# %%
def get_tp_fp_fn(net_output, gt, axes=None, mask=None, square=False):
    """
    net_output must be (b, c, x, y(, z)))
    gt must be a label map (shape (b, 1, x, y(, z)) OR shape (b, x, y(, z))) or one hot encoding (b, c, x, y(, z))
    if mask is provided it must have shape (b, 1, x, y(, z)))
    :param net_output:
    :param gt:
    :param axes:
    :param mask: mask must be 1 for valid pixels and 0 for invalid pixels
    :param square: if True then fp, tp and fn will be squared before summation
    :return:
    """
    if axes is None:
        axes = tuple(range(2, len(net_output.size())))

    shp_x = net_output.shape
    shp_y = gt.shape

    with torch.no_grad():
        if len(shp_x) != len(shp_y):
            gt = gt.view((shp_y[0], 1, *shp_y[1:]))

        if all([i == j for i, j in zip(net_output.shape, gt.shape)]):
            # if this is the case then gt is probably already a one hot encoding
            y_onehot = gt
        else:
            gt = gt.long()
            y_onehot = torch.zeros(shp_x)
            if net_output.device.type == "cuda":
                y_onehot = y_onehot.cuda(net_output.device.index)
            y_onehot.scatter_(1, gt, 1)

    tp = net_output * y_onehot
    fp = net_output * (1 - y_onehot)
    fn = (1 - net_output) * y_onehot

    if mask is not None:
        tp = torch.stack(tuple(x_i * mask[:, 0] for x_i in torch.unbind(tp, dim=1)), dim=1)
        fp = torch.stack(tuple(x_i * mask[:, 0] for x_i in torch.unbind(fp, dim=1)), dim=1)
        fn = torch.stack(tuple(x_i * mask[:, 0] for x_i in torch.unbind(fn, dim=1)), dim=1)

    if square:
        tp = tp ** 2
        fp = fp ** 2
        fn = fn ** 2

    tp = sum_tensor(tp, axes, keepdim=False)
    fp = sum_tensor(fp, axes, keepdim=False)
    fn = sum_tensor(fn, axes, keepdim=False)

    return tp, fp, fn

# %%
class TverskyLoss(nn.Module):
    def __init__(self, apply_nonlin=None, batch_dice=False, do_bg=True, smooth=1.,
                 square=False):
        """
        paper: https://arxiv.org/pdf/1706.05721.pdf
        """
        super(TverskyLoss, self).__init__()

        self.square = square
        self.do_bg = do_bg
        self.batch_dice = batch_dice
        self.apply_nonlin = apply_nonlin
        self.smooth = smooth
        self.alpha = 0.3
        self.beta = 0.7

    def forward(self, x, y, loss_mask=None):
        shp_x = x.shape

        if self.batch_dice:
            axes = [0] + list(range(2, len(shp_x)))
        else:
            axes = list(range(2, len(shp_x)))

        if self.apply_nonlin is not None:
            x = self.apply_nonlin(x)

        tp, fp, fn = get_tp_fp_fn(x, y, axes, loss_mask, self.square)


        tversky = (tp + self.smooth) / (tp + self.alpha*fp + self.beta*fn + self.smooth)

        if not self.do_bg:
            if self.batch_dice:
                tversky = tversky[1:]
            else:
                tversky = tversky[:, 1:]
        tversky = tversky.mean()

        return -tversky

# %%
class FocalTversky_loss(nn.Module):
    """
    paper: https://arxiv.org/pdf/1810.07842.pdf
    author code: https://github.com/nabsabraham/focal-tversky-unet/blob/347d39117c24540400dfe80d106d2fb06d2b99e1/losses.py#L65
    """
    def __init__(self, tversky_kwargs, gamma=0.75):
        super(FocalTversky_loss, self).__init__()
        self.gamma = gamma
        self.tversky = TverskyLoss(**tversky_kwargs)

    def forward(self, net_output, target):
        tversky_loss = 1 + self.tversky(net_output, target) # = 1-tversky(net_output, target)
        focal_tversky = torch.pow(tversky_loss, self.gamma)
        return focal_tversky

# %%
# Loss function 정의
criterion = FocalTversky_loss({'apply_nonlin': softmax_helper, 'batch_dice': True, 'smooth': 1e-5, 'do_bg': True})
# early_stopping : 13번의 epoch 연속으로 val loss 미개선 시에 조기 종료
patience = 13

# %%
#!pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git

# %%
# from warmup_scheduler import GradualWarmupScheduler

# scheduler_steplr = StepLR(optimizer, step_size=10, gamma=0.1)
# scheduler_warmup = GradualWarmupScheduler(optimizer, multiplier=1, total_epoch=5, after_scheduler=scheduler_steplr)

# %%
def train():
    model = smp.DeepLabV3Plus( #PlusPlus
        encoder_name="tu-tf_efficientnetv2_l", # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
        encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
        in_channels=3,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
        classes=11,                     # model output channels (number of classes in your dataset)
        )
    
    
    default_config={
        "optimizer": 'Adam'}
    
    wandb.init(config=default_config)
    config = wandb.config
    
    if config.optimizer == 'Adam':
        optimizer = torch.optim.Adam(params = model.parameters(), lr = learning_rate, betas=(0.9, 0.999), weight_decay=1e-6)
    elif config.optimizer == 'AdamW':
        optimizer = torch.optim.AdamW(params = model.parameters(), lr = learning_rate, betas=(0.9, 0.999), weight_decay=1e-2)
    elif config.optimizer == 'AdamP':
        optimizer = AdamP(params=model.parameters(), lr=learning_rate, betas=(0.9, 0.999), weight_decay=1e-2)
        
    # scheduler 정의
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.3, patience=5, verbose=1)
    # scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max = 60, eta_min = 1e-5)
            
    print(f'Start training..')
    n_class = 11
    best_miou = 0

    for epoch in range(num_epochs):
        model.train()
        hist = np.zeros((n_class, n_class))
        for step, (images, masks, _) in enumerate(train_loader):
            images = torch.stack(images)       
            masks = torch.stack(masks).long() 
            # gpu 연산을 위해 device 할당
            images, masks = images.to(device), masks.to(device)

            # device 할당
            model = model.to(device)
            with amp.autocast(enabled=True):
                # inference
                outputs = model(images)

                # loss 계산 (cross entropy loss)
                loss = criterion(outputs, masks)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            # loss.backward()
            # optimizer.step()
            outputs = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            masks = masks.detach().cpu().numpy()

            hist = add_hist(hist, masks, outputs, n_class=n_class)
            acc, acc_cls, mIoU, fwavacc, IoU = label_accuracy_score(hist)
            # step 주기에 따른 loss 출력
            if (step + 1) % 25 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{step+1}/{len(train_loader)}], \
                        Loss: {round(loss.item(),4)}, mIoU: {round(mIoU,4)}')
                wandb.log({"Train/Loss": round(loss.item(),4),
                           "Train/Accuracy": round(acc,4),
                           "Train/mIoU": round(mIoU,4)})
        wandb.log({"Charts/learning_rate": optimizer.param_groups[0]['lr']})
        
        #scheduler.step()
        
        # validation 주기에 따른 loss 출력 및 best model 저장
        if (epoch + 1) % 1 == 0:
            print(f'Start validation #{epoch +1}')
            val_miou = validation(model)
            
            scheduler.step(val_miou)
            
            if best_miou < val_miou:
                print('trigger times: 0')
                trigger_times = 0
                print(f"Best performance at epoch: {epoch + 1}")
                print(f"Save model in {saved_dir}")
                best_miou = val_miou
                save_model(model, saved_dir)
            else:
                trigger_times += 1
                print('Trigger Times:', trigger_times)
                if trigger_times >= patience:
                    print('Early stopping!\nStart to test process.')
                    return model

# %%
def validation(model):
    model.eval()

    with torch.no_grad():
        n_class = 11
        total_loss = 0
        cnt = 0
        
        hist = np.zeros((n_class, n_class))
        for step, (images, masks, _) in enumerate(val_loader):
            
            images = torch.stack(images)       
            masks = torch.stack(masks).long()  

            images, masks = images.to(device), masks.to(device)            
            
            # device 할당
            model = model.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, masks)
            total_loss += loss
            cnt += 1
            
            outputs = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            masks = masks.detach().cpu().numpy()
            
            hist = add_hist(hist, masks, outputs, n_class=n_class)
             
            # step 주기에 따른 loss 출력
            if (step + 1) % 25 == 0:
                acc, acc_cls, mIoU, fwavacc, IoU = label_accuracy_score(hist)
                wandb.log({"Val/Loss": round(loss.item(),4),
                           "Val/Accuracy": round(acc,4),
                           "Val/mIoU": round(mIoU,4)})

        
        acc, acc_cls, mIoU, fwavacc, IoU = label_accuracy_score(hist)
        IoU_by_class = [{classes : round(IoU,4)} for IoU, classes in zip(IoU , sorted_df['Categories'])]
        
        avrg_loss = total_loss / cnt
        print(f'Validation Average Loss: {round(avrg_loss.item(), 4)}, Accuracy : {round(acc, 4)}, \
                mIoU: {round(mIoU, 4)}')
        print(f'IoU by class : {IoU_by_class}')
        
    return mIoU

# %%
# 모델 저장 함수 정의
val_every = 1

saved_dir = './saved'
# 저장 모델 이름 지정
model_names = 'effv2_unetpp_best.pt'
if not os.path.isdir(saved_dir):                                                           
    os.mkdir(saved_dir)

def save_model(model, saved_dir, file_name=model_names):
    output_path = os.path.join(saved_dir, file_name)
    torch.save(model.state_dict(), output_path)

# %%
# agent에서 위에서 정의한 train 함수를 15번 돌리는 과정
wandb.agent(sweep_id, train, count= 5)
# Out:
# wandb: Agent Starting Run: erhkygr3 with config:
# wandb: 	optimizer: Adam
# wandb: Currently logged in as: fullhouse (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.13.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#                     Syncing run <strong><a href="https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/runs/erhkygr3" target="_blank">comfy-sweep-1</a></strong> to <a href="https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/sweeps/o8rvmjks" target="_blank">https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/sweeps/o8rvmjks</a><br/>
# Start training..
# Epoch [1/100], Step [25/164],                         Loss: 0.9463, mIoU: 0.0444
# Epoch [1/100], Step [50/164],                         Loss: 0.9219, mIoU: 0.0631
# Epoch [1/100], Step [75/164],                         Loss: 0.8917, mIoU: 0.0816
# Epoch [1/100], Step [100/164],                         Loss: 0.8712, mIoU: 0.1003
# Epoch [1/100], Step [125/164],                         Loss: 0.8636, mIoU: 0.1155
# Epoch [1/100], Step [150/164],                         Loss: 0.8368, mIoU: 0.1292
# Start validation #1
# Validation Average Loss: 0.8207, Accuracy : 0.8148,                 mIoU: 0.2468
# IoU by class : [{'Backgroud': 0.8424}, {'General trash': 0.0004}, {'Paper': 0.4757}, {'Paper pack': 0.0001}, {'Metal': 0.0128}, {'Glass': 0.0}, {'Plastic': 0.2688}, {'Styrofoam': 0.4282}, {'Plastic bag': 0.6857}, {'Battery': 0.0}, {'Clothing': 0.0007}]
# trigger times: 0
# Best performance at epoch: 1
# Save model in ./saved
# Epoch [2/100], Step [25/164],                         Loss: 0.838, mIoU: 0.2315
# Epoch [2/100], Step [50/164],                         Loss: 0.7994, mIoU: 0.2468
# Epoch [2/100], Step [75/164],                         Loss: 0.7763, mIoU: 0.2512
# Epoch [2/100], Step [100/164],                         Loss: 0.7685, mIoU: 0.2521
# Epoch [2/100], Step [125/164],                         Loss: 0.732, mIoU: 0.256
# Epoch [2/100], Step [150/164],                         Loss: 0.758, mIoU: 0.2606
# Start validation #2
# Validation Average Loss: 0.7652, Accuracy : 0.8685,                 mIoU: 0.2848
# IoU by class : [{'Backgroud': 0.9091}, {'General trash': 0.0}, {'Paper': 0.6119}, {'Paper pack': 0.0}, {'Metal': 0.0149}, {'Glass': 0.0}, {'Plastic': 0.3017}, {'Styrofoam': 0.5553}, {'Plastic bag': 0.7396}, {'Battery': 0.0}, {'Clothing': 0.0003}]
# trigger times: 0
# Best performance at epoch: 2
# Save model in ./saved
# Epoch [3/100], Step [25/164],                         Loss: 0.7705, mIoU: 0.2744
# Epoch [3/100], Step [50/164],                         Loss: 0.744, mIoU: 0.2854
# Epoch [3/100], Step [75/164],                         Loss: 0.7298, mIoU: 0.2875
# Epoch [3/100], Step [100/164],                         Loss: 0.7469, mIoU: 0.2926
# Epoch [3/100], Step [125/164],                         Loss: 0.7057, mIoU: 0.298
# Epoch [3/100], Step [150/164],                         Loss: 0.6865, mIoU: 0.3037
# Start validation #3
# Validation Average Loss: 0.7392, Accuracy : 0.8837,                 mIoU: 0.3184
# IoU by class : [{'Backgroud': 0.9202}, {'General trash': 0.0005}, {'Paper': 0.6834}, {'Paper pack': 0.0}, {'Metal': 0.1195}, {'Glass': 0.0}, {'Plastic': 0.4392}, {'Styrofoam': 0.5616}, {'Plastic bag': 0.7776}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 3
# Save model in ./saved
# Epoch [4/100], Step [25/164],                         Loss: 0.6796, mIoU: 0.3328
# Epoch [4/100], Step [50/164],                         Loss: 0.7349, mIoU: 0.3361
# Epoch [4/100], Step [75/164],                         Loss: 0.6848, mIoU: 0.3376
# Epoch [4/100], Step [100/164],                         Loss: 0.6488, mIoU: 0.3388
# Epoch [4/100], Step [125/164],                         Loss: 0.6776, mIoU: 0.3461
# Epoch [4/100], Step [150/164],                         Loss: 0.7475, mIoU: 0.3495
# Start validation #4
# Validation Average Loss: 0.7137, Accuracy : 0.8922,                 mIoU: 0.3502
# IoU by class : [{'Backgroud': 0.9323}, {'General trash': 0.3099}, {'Paper': 0.69}, {'Paper pack': 0.0}, {'Metal': 0.1888}, {'Glass': 0.0008}, {'Plastic': 0.3819}, {'Styrofoam': 0.5801}, {'Plastic bag': 0.7685}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 4
# Save model in ./saved
# Epoch [5/100], Step [25/164],                         Loss: 0.653, mIoU: 0.3517
# Epoch [5/100], Step [50/164],                         Loss: 0.6443, mIoU: 0.3683
# Epoch [5/100], Step [75/164],                         Loss: 0.6833, mIoU: 0.3727
# Epoch [5/100], Step [100/164],                         Loss: 0.6502, mIoU: 0.379
# Epoch [5/100], Step [125/164],                         Loss: 0.6888, mIoU: 0.3839
# Epoch [5/100], Step [150/164],                         Loss: 0.6507, mIoU: 0.3866
# Start validation #5
# Validation Average Loss: 0.6934, Accuracy : 0.904,                 mIoU: 0.3943
# IoU by class : [{'Backgroud': 0.9382}, {'General trash': 0.3508}, {'Paper': 0.7065}, {'Paper pack': 0.0036}, {'Metal': 0.1983}, {'Glass': 0.3669}, {'Plastic': 0.3956}, {'Styrofoam': 0.6044}, {'Plastic bag': 0.7732}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 5
# Save model in ./saved
# Epoch [6/100], Step [25/164],                         Loss: 0.6082, mIoU: 0.4257
# Epoch [6/100], Step [50/164],                         Loss: 0.6947, mIoU: 0.4287
# Epoch [6/100], Step [75/164],                         Loss: 0.741, mIoU: 0.4311
# Epoch [6/100], Step [100/164],                         Loss: 0.6267, mIoU: 0.4275
# Epoch [6/100], Step [125/164],                         Loss: 0.7356, mIoU: 0.4302
# Epoch [6/100], Step [150/164],                         Loss: 0.6372, mIoU: 0.4289
# Start validation #6
# Validation Average Loss: 0.6799, Accuracy : 0.9008,                 mIoU: 0.4029
# IoU by class : [{'Backgroud': 0.9353}, {'General trash': 0.3464}, {'Paper': 0.7021}, {'Paper pack': 0.0611}, {'Metal': 0.2757}, {'Glass': 0.3645}, {'Plastic': 0.3695}, {'Styrofoam': 0.5975}, {'Plastic bag': 0.7799}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 6
# Save model in ./saved
# Epoch [7/100], Step [25/164],                         Loss: 0.5804, mIoU: 0.4518
# Epoch [7/100], Step [50/164],                         Loss: 0.4831, mIoU: 0.4511
# Epoch [7/100], Step [75/164],                         Loss: 0.6133, mIoU: 0.4687
# Epoch [7/100], Step [100/164],                         Loss: 0.5675, mIoU: 0.4677
# Epoch [7/100], Step [125/164],                         Loss: 0.5728, mIoU: 0.4689
# Epoch [7/100], Step [150/164],                         Loss: 0.5595, mIoU: 0.4716
# Start validation #7
# Validation Average Loss: 0.6618, Accuracy : 0.9047,                 mIoU: 0.438
# IoU by class : [{'Backgroud': 0.9356}, {'General trash': 0.3957}, {'Paper': 0.7007}, {'Paper pack': 0.2185}, {'Metal': 0.2435}, {'Glass': 0.511}, {'Plastic': 0.4194}, {'Styrofoam': 0.6086}, {'Plastic bag': 0.7849}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 7
# Save model in ./saved
# Epoch [8/100], Step [25/164],                         Loss: 0.5809, mIoU: 0.4788
# Epoch [8/100], Step [50/164],                         Loss: 0.6066, mIoU: 0.489
# Epoch [8/100], Step [75/164],                         Loss: 0.5253, mIoU: 0.4957
# Epoch [8/100], Step [100/164],                         Loss: 0.6728, mIoU: 0.4945
# Epoch [8/100], Step [125/164],                         Loss: 0.5181, mIoU: 0.4964
# Epoch [8/100], Step [150/164],                         Loss: 0.6468, mIoU: 0.4955
# Start validation #8
# Validation Average Loss: 0.6576, Accuracy : 0.9048,                 mIoU: 0.4395
# IoU by class : [{'Backgroud': 0.9385}, {'General trash': 0.3698}, {'Paper': 0.6914}, {'Paper pack': 0.2527}, {'Metal': 0.3803}, {'Glass': 0.3764}, {'Plastic': 0.4083}, {'Styrofoam': 0.6417}, {'Plastic bag': 0.7758}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 8
# Save model in ./saved
# Epoch [9/100], Step [25/164],                         Loss: 0.6133, mIoU: 0.4967
# Epoch [9/100], Step [50/164],                         Loss: 0.648, mIoU: 0.5111
# Epoch [9/100], Step [75/164],                         Loss: 0.5701, mIoU: 0.5167
# Epoch [9/100], Step [100/164],                         Loss: 0.5503, mIoU: 0.5194
# Epoch [9/100], Step [125/164],                         Loss: 0.5903, mIoU: 0.5191
# Epoch [9/100], Step [150/164],                         Loss: 0.5729, mIoU: 0.5164
# Start validation #9
# Validation Average Loss: 0.6542, Accuracy : 0.9073,                 mIoU: 0.4446
# IoU by class : [{'Backgroud': 0.9398}, {'General trash': 0.3545}, {'Paper': 0.7058}, {'Paper pack': 0.2855}, {'Metal': 0.3236}, {'Glass': 0.4686}, {'Plastic': 0.4212}, {'Styrofoam': 0.6046}, {'Plastic bag': 0.7868}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 9
# Save model in ./saved
# Epoch [10/100], Step [25/164],                         Loss: 0.6242, mIoU: 0.5098
# Epoch [10/100], Step [50/164],                         Loss: 0.5354, mIoU: 0.5173
# Epoch [10/100], Step [75/164],                         Loss: 0.6808, mIoU: 0.5089
# Epoch [10/100], Step [100/164],                         Loss: 0.4692, mIoU: 0.5097
# Epoch [10/100], Step [125/164],                         Loss: 0.5186, mIoU: 0.5164
# Epoch [10/100], Step [150/164],                         Loss: 0.6557, mIoU: 0.5226
# Start validation #10
# Validation Average Loss: 0.6431, Accuracy : 0.9107,                 mIoU: 0.4715
# IoU by class : [{'Backgroud': 0.9417}, {'General trash': 0.3735}, {'Paper': 0.7029}, {'Paper pack': 0.3715}, {'Metal': 0.46}, {'Glass': 0.5254}, {'Plastic': 0.4322}, {'Styrofoam': 0.6009}, {'Plastic bag': 0.7783}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 10
# Save model in ./saved
# Epoch [11/100], Step [25/164],                         Loss: 0.5632, mIoU: 0.5838
# Epoch [11/100], Step [50/164],                         Loss: 0.5643, mIoU: 0.5863
# Epoch [11/100], Step [75/164],                         Loss: 0.547, mIoU: 0.5748
# Epoch [11/100], Step [100/164],                         Loss: 0.6023, mIoU: 0.5693
# Epoch [11/100], Step [125/164],                         Loss: 0.5636, mIoU: 0.5662
# Epoch [11/100], Step [150/164],                         Loss: 0.5157, mIoU: 0.5654
# Start validation #11
# Validation Average Loss: 0.6456, Accuracy : 0.912,                 mIoU: 0.4632
# IoU by class : [{'Backgroud': 0.9432}, {'General trash': 0.3884}, {'Paper': 0.6974}, {'Paper pack': 0.3433}, {'Metal': 0.4288}, {'Glass': 0.4381}, {'Plastic': 0.4392}, {'Styrofoam': 0.6293}, {'Plastic bag': 0.7875}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 1
# Epoch [12/100], Step [25/164],                         Loss: 0.6504, mIoU: 0.5884
# Epoch [12/100], Step [50/164],                         Loss: 0.5887, mIoU: 0.5844
# Epoch [12/100], Step [75/164],                         Loss: 0.6612, mIoU: 0.5866
# Epoch [12/100], Step [100/164],                         Loss: 0.4749, mIoU: 0.5825
# Epoch [12/100], Step [125/164],                         Loss: 0.5177, mIoU: 0.5821
# Epoch [12/100], Step [150/164],                         Loss: 0.5511, mIoU: 0.5843
# Start validation #12
# Validation Average Loss: 0.648, Accuracy : 0.9093,                 mIoU: 0.4533
# IoU by class : [{'Backgroud': 0.9401}, {'General trash': 0.3739}, {'Paper': 0.7053}, {'Paper pack': 0.4225}, {'Metal': 0.3561}, {'Glass': 0.4136}, {'Plastic': 0.4192}, {'Styrofoam': 0.5833}, {'Plastic bag': 0.7723}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 2
# Epoch [13/100], Step [25/164],                         Loss: 0.5093, mIoU: 0.5855
# Epoch [13/100], Step [50/164],                         Loss: 0.4744, mIoU: 0.5748
# Epoch [13/100], Step [75/164],                         Loss: 0.6101, mIoU: 0.577
# Epoch [13/100], Step [100/164],                         Loss: 0.5552, mIoU: 0.5837
# Epoch [13/100], Step [125/164],                         Loss: 0.6474, mIoU: 0.5788
# Epoch [13/100], Step [150/164],                         Loss: 0.5983, mIoU: 0.5784
# Start validation #13
# Validation Average Loss: 0.6354, Accuracy : 0.9154,                 mIoU: 0.4733
# IoU by class : [{'Backgroud': 0.9438}, {'General trash': 0.4161}, {'Paper': 0.7202}, {'Paper pack': 0.436}, {'Metal': 0.4357}, {'Glass': 0.3924}, {'Plastic': 0.4027}, {'Styrofoam': 0.6611}, {'Plastic bag': 0.7984}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 13
# Save model in ./saved
# Epoch [14/100], Step [25/164],                         Loss: 0.5358, mIoU: 0.6506
# Epoch [14/100], Step [50/164],                         Loss: 0.5297, mIoU: 0.605
# Epoch [14/100], Step [75/164],                         Loss: 0.4607, mIoU: 0.6096
# Epoch [14/100], Step [100/164],                         Loss: 0.5516, mIoU: 0.605
# Epoch [14/100], Step [125/164],                         Loss: 0.6056, mIoU: 0.606
# Epoch [14/100], Step [150/164],                         Loss: 0.5657, mIoU: 0.6005
# Start validation #14
# Validation Average Loss: 0.6443, Accuracy : 0.911,                 mIoU: 0.466
# IoU by class : [{'Backgroud': 0.9429}, {'General trash': 0.3546}, {'Paper': 0.6796}, {'Paper pack': 0.4228}, {'Metal': 0.4285}, {'Glass': 0.4669}, {'Plastic': 0.4468}, {'Styrofoam': 0.6047}, {'Plastic bag': 0.7791}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 1
# Epoch [15/100], Step [25/164],                         Loss: 0.6298, mIoU: 0.6216
# Epoch [15/100], Step [50/164],                         Loss: 0.5039, mIoU: 0.6132
# Epoch [15/100], Step [75/164],                         Loss: 0.5873, mIoU: 0.6056
# Epoch [15/100], Step [100/164],                         Loss: 0.5476, mIoU: 0.6098
# Epoch [15/100], Step [125/164],                         Loss: 0.5835, mIoU: 0.6086
# Epoch [15/100], Step [150/164],                         Loss: 0.6716, mIoU: 0.6051
# Start validation #15
# Validation Average Loss: 0.6371, Accuracy : 0.9164,                 mIoU: 0.4854
# IoU by class : [{'Backgroud': 0.946}, {'General trash': 0.3845}, {'Paper': 0.713}, {'Paper pack': 0.5013}, {'Metal': 0.4344}, {'Glass': 0.4971}, {'Plastic': 0.442}, {'Styrofoam': 0.6282}, {'Plastic bag': 0.7933}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 15
# Save model in ./saved
# Epoch [16/100], Step [25/164],                         Loss: 0.6379, mIoU: 0.6394
# Epoch [16/100], Step [50/164],                         Loss: 0.4585, mIoU: 0.6364
# Epoch [16/100], Step [75/164],                         Loss: 0.4888, mIoU: 0.6184
# Epoch [16/100], Step [100/164],                         Loss: 0.5021, mIoU: 0.6206
# Epoch [16/100], Step [125/164],                         Loss: 0.569, mIoU: 0.62
# Epoch [16/100], Step [150/164],                         Loss: 0.4699, mIoU: 0.6206
# Start validation #16
# Validation Average Loss: 0.6491, Accuracy : 0.9122,                 mIoU: 0.4611
# IoU by class : [{'Backgroud': 0.9445}, {'General trash': 0.3198}, {'Paper': 0.6864}, {'Paper pack': 0.3933}, {'Metal': 0.3887}, {'Glass': 0.4945}, {'Plastic': 0.4181}, {'Styrofoam': 0.6416}, {'Plastic bag': 0.7851}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 1
# Epoch [17/100], Step [25/164],                         Loss: 0.5087, mIoU: 0.6401
# Epoch [17/100], Step [50/164],                         Loss: 0.5744, mIoU: 0.6227
# Epoch [17/100], Step [75/164],                         Loss: 0.5465, mIoU: 0.6277
# Epoch [17/100], Step [100/164],                         Loss: 0.6433, mIoU: 0.6308
# Epoch [17/100], Step [125/164],                         Loss: 0.4573, mIoU: 0.625
# Epoch [17/100], Step [150/164],                         Loss: 0.4618, mIoU: 0.6218
# Start validation #17
# Validation Average Loss: 0.6298, Accuracy : 0.9192,                 mIoU: 0.491
# IoU by class : [{'Backgroud': 0.9472}, {'General trash': 0.4042}, {'Paper': 0.7266}, {'Paper pack': 0.4753}, {'Metal': 0.4261}, {'Glass': 0.5099}, {'Plastic': 0.4554}, {'Styrofoam': 0.6624}, {'Plastic bag': 0.7941}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 17
# Save model in ./saved
# Epoch [18/100], Step [25/164],                         Loss: 0.5586, mIoU: 0.622
# Epoch [18/100], Step [50/164],                         Loss: 0.5158, mIoU: 0.619
# Epoch [18/100], Step [75/164],                         Loss: 0.5769, mIoU: 0.6144
# Epoch [18/100], Step [100/164],                         Loss: 0.4364, mIoU: 0.615
# Epoch [18/100], Step [125/164],                         Loss: 0.5441, mIoU: 0.6243
# Epoch [18/100], Step [150/164],                         Loss: 0.567, mIoU: 0.6273
# Start validation #18
# Validation Average Loss: 0.6374, Accuracy : 0.9203,                 mIoU: 0.5049
# IoU by class : [{'Backgroud': 0.9468}, {'General trash': 0.4388}, {'Paper': 0.7304}, {'Paper pack': 0.5064}, {'Metal': 0.456}, {'Glass': 0.5942}, {'Plastic': 0.4555}, {'Styrofoam': 0.6376}, {'Plastic bag': 0.7887}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 18
# Save model in ./saved
# Epoch [19/100], Step [25/164],                         Loss: 0.5044, mIoU: 0.6504
# Epoch [19/100], Step [50/164],                         Loss: 0.4129, mIoU: 0.6504
# Epoch [19/100], Step [75/164],                         Loss: 0.525, mIoU: 0.6481
# Epoch [19/100], Step [100/164],                         Loss: 0.4342, mIoU: 0.6517
# Epoch [19/100], Step [125/164],                         Loss: 0.5089, mIoU: 0.6457
# Epoch [19/100], Step [150/164],                         Loss: 0.3784, mIoU: 0.6434
# Start validation #19
# Validation Average Loss: 0.636, Accuracy : 0.9201,                 mIoU: 0.498
# IoU by class : [{'Backgroud': 0.9452}, {'General trash': 0.4309}, {'Paper': 0.7125}, {'Paper pack': 0.5368}, {'Metal': 0.3545}, {'Glass': 0.5708}, {'Plastic': 0.4779}, {'Styrofoam': 0.6489}, {'Plastic bag': 0.8001}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 1
# Epoch [20/100], Step [25/164],                         Loss: 0.429, mIoU: 0.6654
# Epoch [20/100], Step [50/164],                         Loss: 0.4115, mIoU: 0.6421
# Epoch [20/100], Step [75/164],                         Loss: 0.6287, mIoU: 0.6526
# Epoch [20/100], Step [100/164],                         Loss: 0.5404, mIoU: 0.6536
# Epoch [20/100], Step [125/164],                         Loss: 0.582, mIoU: 0.6534
# Epoch [20/100], Step [150/164],                         Loss: 0.4351, mIoU: 0.6562
# Start validation #20
# Validation Average Loss: 0.6343, Accuracy : 0.9153,                 mIoU: 0.4783
# IoU by class : [{'Backgroud': 0.9444}, {'General trash': 0.4313}, {'Paper': 0.6971}, {'Paper pack': 0.4048}, {'Metal': 0.4192}, {'Glass': 0.5206}, {'Plastic': 0.4205}, {'Styrofoam': 0.6234}, {'Plastic bag': 0.7996}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 2
# Epoch [21/100], Step [25/164],                         Loss: 0.5413, mIoU: 0.6237
# Epoch [21/100], Step [50/164],                         Loss: 0.6189, mIoU: 0.6402
# Epoch [21/100], Step [75/164],                         Loss: 0.4111, mIoU: 0.6441
# Epoch [21/100], Step [100/164],                         Loss: 0.5242, mIoU: 0.6453
# Epoch [21/100], Step [125/164],                         Loss: 0.4704, mIoU: 0.645
# Epoch [21/100], Step [150/164],                         Loss: 0.666, mIoU: 0.6393
# Start validation #21
# Validation Average Loss: 0.6315, Accuracy : 0.9212,                 mIoU: 0.4984
# IoU by class : [{'Backgroud': 0.9454}, {'General trash': 0.4312}, {'Paper': 0.7263}, {'Paper pack': 0.5154}, {'Metal': 0.383}, {'Glass': 0.5293}, {'Plastic': 0.4585}, {'Styrofoam': 0.6868}, {'Plastic bag': 0.8063}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 3
# Epoch [22/100], Step [25/164],                         Loss: 0.4334, mIoU: 0.6615
# Epoch [22/100], Step [50/164],                         Loss: 0.4289, mIoU: 0.6604
# Epoch [22/100], Step [75/164],                         Loss: 0.5591, mIoU: 0.6644
# Epoch [22/100], Step [100/164],                         Loss: 0.3771, mIoU: 0.6649
# Epoch [22/100], Step [125/164],                         Loss: 0.5754, mIoU: 0.66
# Epoch [22/100], Step [150/164],                         Loss: 0.3946, mIoU: 0.6587
# Start validation #22
# Validation Average Loss: 0.6383, Accuracy : 0.9173,                 mIoU: 0.4834
# IoU by class : [{'Backgroud': 0.9455}, {'General trash': 0.4453}, {'Paper': 0.7243}, {'Paper pack': 0.4525}, {'Metal': 0.3453}, {'Glass': 0.5821}, {'Plastic': 0.4403}, {'Styrofoam': 0.6048}, {'Plastic bag': 0.7771}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 4
# Epoch [23/100], Step [25/164],                         Loss: 0.5139, mIoU: 0.6568
# Epoch [23/100], Step [50/164],                         Loss: 0.4872, mIoU: 0.6584
# Epoch [23/100], Step [75/164],                         Loss: 0.4752, mIoU: 0.6548
# Epoch [23/100], Step [100/164],                         Loss: 0.3843, mIoU: 0.6525
# Epoch [23/100], Step [125/164],                         Loss: 0.5453, mIoU: 0.6517
# Epoch [23/100], Step [150/164],                         Loss: 0.4456, mIoU: 0.6509
# Start validation #23
# Validation Average Loss: 0.6235, Accuracy : 0.9188,                 mIoU: 0.4933
# IoU by class : [{'Backgroud': 0.9456}, {'General trash': 0.4243}, {'Paper': 0.716}, {'Paper pack': 0.4612}, {'Metal': 0.4654}, {'Glass': 0.5299}, {'Plastic': 0.4521}, {'Styrofoam': 0.6375}, {'Plastic bag': 0.7944}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 5
# Epoch [24/100], Step [25/164],                         Loss: 0.4231, mIoU: 0.6441
# Epoch [24/100], Step [50/164],                         Loss: 0.4065, mIoU: 0.6389
# Epoch [24/100], Step [75/164],                         Loss: 0.4529, mIoU: 0.643
# Epoch [24/100], Step [100/164],                         Loss: 0.4947, mIoU: 0.6441
# Epoch [24/100], Step [125/164],                         Loss: 0.5804, mIoU: 0.6454
# Epoch [24/100], Step [150/164],                         Loss: 0.5875, mIoU: 0.6461
# Start validation #24
# Validation Average Loss: 0.6283, Accuracy : 0.915,                 mIoU: 0.4783
# IoU by class : [{'Backgroud': 0.9445}, {'General trash': 0.3715}, {'Paper': 0.7131}, {'Paper pack': 0.5239}, {'Metal': 0.3993}, {'Glass': 0.4571}, {'Plastic': 0.4304}, {'Styrofoam': 0.6319}, {'Plastic bag': 0.7893}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch 00024: reducing learning rate of group 0 to 3.0000e-05.
# Trigger Times: 6
# Epoch [25/100], Step [25/164],                         Loss: 0.5513, mIoU: 0.638
# Epoch [25/100], Step [50/164],                         Loss: 0.4429, mIoU: 0.6536
# Epoch [25/100], Step [75/164],                         Loss: 0.5008, mIoU: 0.661
# Epoch [25/100], Step [100/164],                         Loss: 0.3973, mIoU: 0.6666
# Epoch [25/100], Step [125/164],                         Loss: 0.5499, mIoU: 0.6655
# Epoch [25/100], Step [150/164],                         Loss: 0.5158, mIoU: 0.6675
# Start validation #25
# Validation Average Loss: 0.6236, Accuracy : 0.9231,                 mIoU: 0.5039
# IoU by class : [{'Backgroud': 0.9464}, {'General trash': 0.4203}, {'Paper': 0.7372}, {'Paper pack': 0.5007}, {'Metal': 0.4259}, {'Glass': 0.5446}, {'Plastic': 0.4826}, {'Styrofoam': 0.6817}, {'Plastic bag': 0.8033}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 7
# Epoch [26/100], Step [25/164],                         Loss: 0.4918, mIoU: 0.6856
# Epoch [26/100], Step [50/164],                         Loss: 0.544, mIoU: 0.6819
# Epoch [26/100], Step [75/164],                         Loss: 0.401, mIoU: 0.6809
# Epoch [26/100], Step [100/164],                         Loss: 0.4591, mIoU: 0.6793
# Epoch [26/100], Step [125/164],                         Loss: 0.6208, mIoU: 0.6786
# Epoch [26/100], Step [150/164],                         Loss: 0.4724, mIoU: 0.6777
# Start validation #26
# Validation Average Loss: 0.6297, Accuracy : 0.924,                 mIoU: 0.5088
# IoU by class : [{'Backgroud': 0.9465}, {'General trash': 0.4215}, {'Paper': 0.7328}, {'Paper pack': 0.5533}, {'Metal': 0.4161}, {'Glass': 0.5677}, {'Plastic': 0.4854}, {'Styrofoam': 0.6596}, {'Plastic bag': 0.8138}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 26
# Save model in ./saved
# Epoch [27/100], Step [25/164],                         Loss: 0.5595, mIoU: 0.6838
# Epoch [27/100], Step [50/164],                         Loss: 0.3535, mIoU: 0.6782
# Epoch [27/100], Step [75/164],                         Loss: 0.5834, mIoU: 0.6837
# Epoch [27/100], Step [100/164],                         Loss: 0.5233, mIoU: 0.6839
# Epoch [27/100], Step [125/164],                         Loss: 0.5916, mIoU: 0.6805
# Epoch [27/100], Step [150/164],                         Loss: 0.502, mIoU: 0.6801
# Start validation #27
# Validation Average Loss: 0.6218, Accuracy : 0.9232,                 mIoU: 0.5036
# IoU by class : [{'Backgroud': 0.9485}, {'General trash': 0.4293}, {'Paper': 0.73}, {'Paper pack': 0.5528}, {'Metal': 0.4215}, {'Glass': 0.5298}, {'Plastic': 0.4608}, {'Styrofoam': 0.6595}, {'Plastic bag': 0.8072}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 1
# Epoch [28/100], Step [25/164],                         Loss: 0.3985, mIoU: 0.6858
# Epoch [28/100], Step [50/164],                         Loss: 0.4429, mIoU: 0.6884
# Epoch [28/100], Step [75/164],                         Loss: 0.4067, mIoU: 0.6828
# Epoch [28/100], Step [100/164],                         Loss: 0.3947, mIoU: 0.684
# Epoch [28/100], Step [125/164],                         Loss: 0.5801, mIoU: 0.684
# Epoch [28/100], Step [150/164],                         Loss: 0.5317, mIoU: 0.6822
# Start validation #28
# Validation Average Loss: 0.6144, Accuracy : 0.9236,                 mIoU: 0.5075
# IoU by class : [{'Backgroud': 0.9475}, {'General trash': 0.4237}, {'Paper': 0.7395}, {'Paper pack': 0.5545}, {'Metal': 0.4445}, {'Glass': 0.5245}, {'Plastic': 0.4739}, {'Styrofoam': 0.6653}, {'Plastic bag': 0.809}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 2
# Epoch [29/100], Step [25/164],                         Loss: 0.4192, mIoU: 0.6663
# Epoch [29/100], Step [50/164],                         Loss: 0.3736, mIoU: 0.6745
# Epoch [29/100], Step [75/164],                         Loss: 0.522, mIoU: 0.6815
# Epoch [29/100], Step [100/164],                         Loss: 0.3625, mIoU: 0.6803
# Epoch [29/100], Step [125/164],                         Loss: 0.4705, mIoU: 0.6812
# Epoch [29/100], Step [150/164],                         Loss: 0.5828, mIoU: 0.6854
# Start validation #29
# Validation Average Loss: 0.6221, Accuracy : 0.9238,                 mIoU: 0.5029
# IoU by class : [{'Backgroud': 0.9472}, {'General trash': 0.4262}, {'Paper': 0.7351}, {'Paper pack': 0.5109}, {'Metal': 0.4163}, {'Glass': 0.5496}, {'Plastic': 0.4665}, {'Styrofoam': 0.6659}, {'Plastic bag': 0.8143}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 3
# Epoch [30/100], Step [25/164],                         Loss: 0.4217, mIoU: 0.6938
# Epoch [30/100], Step [50/164],                         Loss: 0.5342, mIoU: 0.6952
# Epoch [30/100], Step [75/164],                         Loss: 0.4422, mIoU: 0.6882
# Epoch [30/100], Step [100/164],                         Loss: 0.4004, mIoU: 0.6827
# Epoch [30/100], Step [125/164],                         Loss: 0.4405, mIoU: 0.6831
# Epoch [30/100], Step [150/164],                         Loss: 0.5142, mIoU: 0.6867
# Start validation #30
# Validation Average Loss: 0.622, Accuracy : 0.924,                 mIoU: 0.5089
# IoU by class : [{'Backgroud': 0.9464}, {'General trash': 0.4206}, {'Paper': 0.7384}, {'Paper pack': 0.5511}, {'Metal': 0.4152}, {'Glass': 0.5811}, {'Plastic': 0.4682}, {'Styrofoam': 0.6633}, {'Plastic bag': 0.8139}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 30
# Save model in ./saved
# Epoch [31/100], Step [25/164],                         Loss: 0.534, mIoU: 0.6872
# Epoch [31/100], Step [50/164],                         Loss: 0.426, mIoU: 0.6823
# Epoch [31/100], Step [75/164],                         Loss: 0.4438, mIoU: 0.6909
# Epoch [31/100], Step [100/164],                         Loss: 0.5101, mIoU: 0.6928
# Epoch [31/100], Step [125/164],                         Loss: 0.58, mIoU: 0.6912
# Epoch [31/100], Step [150/164],                         Loss: 0.4619, mIoU: 0.6901
# Start validation #31
# Validation Average Loss: 0.6203, Accuracy : 0.9234,                 mIoU: 0.5096
# IoU by class : [{'Backgroud': 0.9486}, {'General trash': 0.4164}, {'Paper': 0.7315}, {'Paper pack': 0.55}, {'Metal': 0.4443}, {'Glass': 0.5942}, {'Plastic': 0.455}, {'Styrofoam': 0.6544}, {'Plastic bag': 0.8109}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 31
# Save model in ./saved
# Epoch [32/100], Step [25/164],                         Loss: 0.4854, mIoU: 0.7042
# Epoch [32/100], Step [50/164],                         Loss: 0.3729, mIoU: 0.6956
# Epoch [32/100], Step [75/164],                         Loss: 0.464, mIoU: 0.6996
# Epoch [32/100], Step [100/164],                         Loss: 0.5349, mIoU: 0.698
# Epoch [32/100], Step [125/164],                         Loss: 0.4519, mIoU: 0.6883
# Epoch [32/100], Step [150/164],                         Loss: 0.3457, mIoU: 0.6917
# Start validation #32
# Validation Average Loss: 0.6194, Accuracy : 0.9233,                 mIoU: 0.5054
# IoU by class : [{'Backgroud': 0.9479}, {'General trash': 0.4259}, {'Paper': 0.7314}, {'Paper pack': 0.5341}, {'Metal': 0.4248}, {'Glass': 0.5458}, {'Plastic': 0.477}, {'Styrofoam': 0.6636}, {'Plastic bag': 0.8088}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 1
# Epoch [33/100], Step [25/164],                         Loss: 0.65, mIoU: 0.6774
# Epoch [33/100], Step [50/164],                         Loss: 0.4524, mIoU: 0.6845
# Epoch [33/100], Step [75/164],                         Loss: 0.5193, mIoU: 0.6908
# Epoch [33/100], Step [100/164],                         Loss: 0.4362, mIoU: 0.6925
# Epoch [33/100], Step [125/164],                         Loss: 0.5068, mIoU: 0.6906
# Epoch [33/100], Step [150/164],                         Loss: 0.4604, mIoU: 0.6934
# Start validation #33
# Validation Average Loss: 0.619, Accuracy : 0.9256,                 mIoU: 0.5176
# IoU by class : [{'Backgroud': 0.9478}, {'General trash': 0.4335}, {'Paper': 0.7374}, {'Paper pack': 0.5674}, {'Metal': 0.4586}, {'Glass': 0.564}, {'Plastic': 0.495}, {'Styrofoam': 0.6739}, {'Plastic bag': 0.8159}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 33
# Save model in ./saved
# Epoch [34/100], Step [25/164],                         Loss: 0.5031, mIoU: 0.6927
# Epoch [34/100], Step [50/164],                         Loss: 0.5293, mIoU: 0.6965
# Epoch [34/100], Step [75/164],                         Loss: 0.6132, mIoU: 0.6952
# Epoch [34/100], Step [100/164],                         Loss: 0.4311, mIoU: 0.6941
# Epoch [34/100], Step [125/164],                         Loss: 0.5221, mIoU: 0.6928
# Epoch [34/100], Step [150/164],                         Loss: 0.4318, mIoU: 0.6935
# Start validation #34
# Validation Average Loss: 0.6219, Accuracy : 0.9257,                 mIoU: 0.5132
# IoU by class : [{'Backgroud': 0.9477}, {'General trash': 0.4608}, {'Paper': 0.7424}, {'Paper pack': 0.4926}, {'Metal': 0.4544}, {'Glass': 0.5727}, {'Plastic': 0.4864}, {'Styrofoam': 0.6759}, {'Plastic bag': 0.8122}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 1
# Epoch [35/100], Step [25/164],                         Loss: 0.4753, mIoU: 0.6907
# Epoch [35/100], Step [50/164],                         Loss: 0.4411, mIoU: 0.6929
# Epoch [35/100], Step [75/164],                         Loss: 0.4861, mIoU: 0.6936
# Epoch [35/100], Step [100/164],                         Loss: 0.4295, mIoU: 0.6927
# Epoch [35/100], Step [125/164],                         Loss: 0.433, mIoU: 0.6934
# Epoch [35/100], Step [150/164],                         Loss: 0.442, mIoU: 0.6959
# Start validation #35
# Validation Average Loss: 0.6209, Accuracy : 0.9247,                 mIoU: 0.5174
# IoU by class : [{'Backgroud': 0.949}, {'General trash': 0.4484}, {'Paper': 0.7436}, {'Paper pack': 0.5122}, {'Metal': 0.4893}, {'Glass': 0.612}, {'Plastic': 0.4785}, {'Styrofoam': 0.6544}, {'Plastic bag': 0.8042}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 2
# Epoch [36/100], Step [25/164],                         Loss: 0.3529, mIoU: 0.6963
# Epoch [36/100], Step [50/164],                         Loss: 0.526, mIoU: 0.7006
# Epoch [36/100], Step [75/164],                         Loss: 0.5966, mIoU: 0.7035
# Epoch [36/100], Step [100/164],                         Loss: 0.4433, mIoU: 0.7022
# Epoch [36/100], Step [125/164],                         Loss: 0.5066, mIoU: 0.7024
# Epoch [36/100], Step [150/164],                         Loss: 0.4428, mIoU: 0.7003
# Start validation #36
# Validation Average Loss: 0.6269, Accuracy : 0.9251,                 mIoU: 0.5113
# IoU by class : [{'Backgroud': 0.9493}, {'General trash': 0.4267}, {'Paper': 0.7303}, {'Paper pack': 0.4865}, {'Metal': 0.4884}, {'Glass': 0.6035}, {'Plastic': 0.4723}, {'Styrofoam': 0.6503}, {'Plastic bag': 0.8171}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 3
# Epoch [37/100], Step [25/164],                         Loss: 0.5453, mIoU: 0.6859
# Epoch [37/100], Step [50/164],                         Loss: 0.4931, mIoU: 0.6847
# Epoch [37/100], Step [75/164],                         Loss: 0.3189, mIoU: 0.6929
# Epoch [37/100], Step [100/164],                         Loss: 0.4324, mIoU: 0.6938
# Epoch [37/100], Step [125/164],                         Loss: 0.5138, mIoU: 0.6949
# Epoch [37/100], Step [150/164],                         Loss: 0.4449, mIoU: 0.6985
# Start validation #37
# Validation Average Loss: 0.6214, Accuracy : 0.9243,                 mIoU: 0.5089
# IoU by class : [{'Backgroud': 0.9475}, {'General trash': 0.4469}, {'Paper': 0.7356}, {'Paper pack': 0.4708}, {'Metal': 0.4663}, {'Glass': 0.5914}, {'Plastic': 0.4612}, {'Styrofoam': 0.6637}, {'Plastic bag': 0.8138}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 4
# Epoch [38/100], Step [25/164],                         Loss: 0.4251, mIoU: 0.6964
# Epoch [38/100], Step [50/164],                         Loss: 0.3206, mIoU: 0.7026
# Epoch [38/100], Step [75/164],                         Loss: 0.5284, mIoU: 0.6988
# Epoch [38/100], Step [100/164],                         Loss: 0.4473, mIoU: 0.6981
# Epoch [38/100], Step [125/164],                         Loss: 0.4352, mIoU: 0.7008
# Epoch [38/100], Step [150/164],                         Loss: 0.4434, mIoU: 0.7019
# Start validation #38
# Validation Average Loss: 0.6201, Accuracy : 0.9256,                 mIoU: 0.5133
# IoU by class : [{'Backgroud': 0.9481}, {'General trash': 0.472}, {'Paper': 0.7441}, {'Paper pack': 0.4904}, {'Metal': 0.4676}, {'Glass': 0.5739}, {'Plastic': 0.4405}, {'Styrofoam': 0.6937}, {'Plastic bag': 0.8164}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 5
# Epoch [39/100], Step [25/164],                         Loss: 0.464, mIoU: 0.706
# Epoch [39/100], Step [50/164],                         Loss: 0.437, mIoU: 0.7111
# Epoch [39/100], Step [75/164],                         Loss: 0.5104, mIoU: 0.7113
# Epoch [39/100], Step [100/164],                         Loss: 0.4267, mIoU: 0.7088
# Epoch [39/100], Step [125/164],                         Loss: 0.5672, mIoU: 0.7063
# Epoch [39/100], Step [150/164],                         Loss: 0.4449, mIoU: 0.7052
# Start validation #39
# Validation Average Loss: 0.6202, Accuracy : 0.9245,                 mIoU: 0.5156
# IoU by class : [{'Backgroud': 0.9464}, {'General trash': 0.4644}, {'Paper': 0.7348}, {'Paper pack': 0.5046}, {'Metal': 0.472}, {'Glass': 0.5959}, {'Plastic': 0.4538}, {'Styrofoam': 0.6792}, {'Plastic bag': 0.8209}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch 00039: reducing learning rate of group 0 to 9.0000e-06.
# Trigger Times: 6
# Epoch [40/100], Step [25/164],                         Loss: 0.5409, mIoU: 0.6983
# Epoch [40/100], Step [50/164],                         Loss: 0.414, mIoU: 0.7022
# Epoch [40/100], Step [75/164],                         Loss: 0.407, mIoU: 0.6978
# Epoch [40/100], Step [100/164],                         Loss: 0.5363, mIoU: 0.6971
# Epoch [40/100], Step [125/164],                         Loss: 0.4317, mIoU: 0.7003
# Epoch [40/100], Step [150/164],                         Loss: 0.4063, mIoU: 0.7012
# Start validation #40
# Validation Average Loss: 0.6228, Accuracy : 0.9233,                 mIoU: 0.5125
# IoU by class : [{'Backgroud': 0.9474}, {'General trash': 0.4287}, {'Paper': 0.7219}, {'Paper pack': 0.491}, {'Metal': 0.4932}, {'Glass': 0.6064}, {'Plastic': 0.4655}, {'Styrofoam': 0.6669}, {'Plastic bag': 0.8162}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 7
# Epoch [41/100], Step [25/164],                         Loss: 0.6283, mIoU: 0.709
# Epoch [41/100], Step [50/164],                         Loss: 0.437, mIoU: 0.7009
# Epoch [41/100], Step [75/164],                         Loss: 0.5207, mIoU: 0.6969
# Epoch [41/100], Step [100/164],                         Loss: 0.4581, mIoU: 0.6994
# Epoch [41/100], Step [125/164],                         Loss: 0.516, mIoU: 0.702
# Epoch [41/100], Step [150/164],                         Loss: 0.467, mIoU: 0.7034
# Start validation #41
# Validation Average Loss: 0.6211, Accuracy : 0.9252,                 mIoU: 0.5131
# IoU by class : [{'Backgroud': 0.9474}, {'General trash': 0.4421}, {'Paper': 0.7352}, {'Paper pack': 0.4637}, {'Metal': 0.4916}, {'Glass': 0.6052}, {'Plastic': 0.4726}, {'Styrofoam': 0.6686}, {'Plastic bag': 0.8176}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 8
# Epoch [42/100], Step [25/164],                         Loss: 0.4254, mIoU: 0.6997
# Epoch [42/100], Step [50/164],                         Loss: 0.448, mIoU: 0.7088
# Epoch [42/100], Step [75/164],                         Loss: 0.4648, mIoU: 0.7081
# Epoch [42/100], Step [100/164],                         Loss: 0.5076, mIoU: 0.7078
# Epoch [42/100], Step [125/164],                         Loss: 0.5359, mIoU: 0.7061
# Epoch [42/100], Step [150/164],                         Loss: 0.4373, mIoU: 0.7066
# Start validation #42
# Validation Average Loss: 0.6175, Accuracy : 0.9253,                 mIoU: 0.5147
# IoU by class : [{'Backgroud': 0.9484}, {'General trash': 0.4485}, {'Paper': 0.7388}, {'Paper pack': 0.4736}, {'Metal': 0.4888}, {'Glass': 0.6078}, {'Plastic': 0.47}, {'Styrofoam': 0.6703}, {'Plastic bag': 0.8149}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 9
# Epoch [43/100], Step [25/164],                         Loss: 0.4141, mIoU: 0.6935
# Epoch [43/100], Step [50/164],                         Loss: 0.4706, mIoU: 0.7017
# Epoch [43/100], Step [75/164],                         Loss: 0.4217, mIoU: 0.7023
# Epoch [43/100], Step [100/164],                         Loss: 0.3912, mIoU: 0.7033
# Epoch [43/100], Step [125/164],                         Loss: 0.4825, mIoU: 0.704
# Epoch [43/100], Step [150/164],                         Loss: 0.5104, mIoU: 0.7056
# Start validation #43
# Validation Average Loss: 0.6261, Accuracy : 0.9258,                 mIoU: 0.5145
# IoU by class : [{'Backgroud': 0.948}, {'General trash': 0.4511}, {'Paper': 0.7337}, {'Paper pack': 0.4924}, {'Metal': 0.4703}, {'Glass': 0.5999}, {'Plastic': 0.4672}, {'Styrofoam': 0.6792}, {'Plastic bag': 0.8173}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 10
# Epoch [44/100], Step [25/164],                         Loss: 0.4151, mIoU: 0.7189
# Epoch [44/100], Step [50/164],                         Loss: 0.4805, mIoU: 0.7133
# Epoch [44/100], Step [75/164],                         Loss: 0.5327, mIoU: 0.7125
# Epoch [44/100], Step [100/164],                         Loss: 0.3624, mIoU: 0.711
# Epoch [44/100], Step [125/164],                         Loss: 0.4406, mIoU: 0.7073
# Epoch [44/100], Step [150/164],                         Loss: 0.6057, mIoU: 0.7104
# Start validation #44
# Validation Average Loss: 0.6206, Accuracy : 0.9253,                 mIoU: 0.5145
# IoU by class : [{'Backgroud': 0.9485}, {'General trash': 0.4478}, {'Paper': 0.7347}, {'Paper pack': 0.4808}, {'Metal': 0.4849}, {'Glass': 0.5885}, {'Plastic': 0.4748}, {'Styrofoam': 0.683}, {'Plastic bag': 0.8164}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 11
# Epoch [45/100], Step [25/164],                         Loss: 0.4231, mIoU: 0.7823
# Epoch [45/100], Step [50/164],                         Loss: 0.5326, mIoU: 0.7093
# Epoch [45/100], Step [75/164],                         Loss: 0.4238, mIoU: 0.7103
# Epoch [45/100], Step [100/164],                         Loss: 0.5097, mIoU: 0.7088
# Epoch [45/100], Step [125/164],                         Loss: 0.5546, mIoU: 0.7071
# Epoch [45/100], Step [150/164],                         Loss: 0.4834, mIoU: 0.7064
# Start validation #45
# Validation Average Loss: 0.6224, Accuracy : 0.9246,                 mIoU: 0.5113
# IoU by class : [{'Backgroud': 0.9486}, {'General trash': 0.4375}, {'Paper': 0.7296}, {'Paper pack': 0.4988}, {'Metal': 0.4739}, {'Glass': 0.5851}, {'Plastic': 0.4712}, {'Styrofoam': 0.6636}, {'Plastic bag': 0.8164}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch 00045: reducing learning rate of group 0 to 2.7000e-06.
# Trigger Times: 12
# Epoch [46/100], Step [25/164],                         Loss: 0.3379, mIoU: 0.7088
# Epoch [46/100], Step [50/164],                         Loss: 0.4492, mIoU: 0.7126
# Epoch [46/100], Step [75/164],                         Loss: 0.3381, mIoU: 0.7122
# Epoch [46/100], Step [100/164],                         Loss: 0.4391, mIoU: 0.709
# Epoch [46/100], Step [125/164],                         Loss: 0.4572, mIoU: 0.7088
# Epoch [46/100], Step [150/164],                         Loss: 0.519, mIoU: 0.7087
# Start validation #46
# Validation Average Loss: 0.6227, Accuracy : 0.9259,                 mIoU: 0.5163
# IoU by class : [{'Backgroud': 0.9479}, {'General trash': 0.4473}, {'Paper': 0.7397}, {'Paper pack': 0.4814}, {'Metal': 0.4811}, {'Glass': 0.6212}, {'Plastic': 0.4759}, {'Styrofoam': 0.6651}, {'Plastic bag': 0.8195}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 13
# Early stopping!
# Start to test process.
# <br/>Waiting for W&B process to finish, PID 20306... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Charts/learning_rate</td><td>█████████████████████▃▃▃▃▃▃▃▃▃▃▃▃▃▁▁▁▁▁▁</td></tr><tr><td>Train/Accuracy</td><td>▁▆▇▇▇▇▇▇▇███████████████████████████████</td></tr><tr><td>Train/Loss</td><td>█▇▆▆▅▅▅▄▄▅▄▄▄▃▅▄▂▂▂▂▂▂▃▃▄▄▃▁▂▂▄▂▁▂▂▃▂▃▃▄</td></tr><tr><td>Train/mIoU</td><td>▁▃▃▄▄▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇██████████████████</td></tr><tr><td>Val/Accuracy</td><td>▁▅▆▆▇▆▇▇▇▇▇▇▇▇█▇▇▇█▇▇███████████████████</td></tr><tr><td>Val/Loss</td><td>█▆▅▅▄▄▃▃▂▁▃▅▄▃▃▂▃▁▂▄▃▃▃▃▂▄▃▃▃▃▃▃▃▂▃▂▂▂▂▂</td></tr><tr><td>Val/mIoU</td><td>▁▂▃▄▅▅▆▆▇▇▆▇▇▇▇▇▇▇▇▇▇██▇████████████████</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Charts/learning_rate</td><td>0.0</td></tr><tr><td>Train/Accuracy</td><td>0.9619</td></tr><tr><td>Train/Loss</td><td>0.519</td></tr><tr><td>Train/mIoU</td><td>0.7087</td></tr><tr><td>Val/Accuracy</td><td>0.9336</td></tr><tr><td>Val/Loss</td><td>0.6636</td></tr><tr><td>Val/mIoU</td><td>0.5257</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">comfy-sweep-1</strong>: <a href="https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/runs/erhkygr3" target="_blank">https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/runs/erhkygr3</a><br/>
# Find logs at: <code>./wandb/run-20221222_115538-erhkygr3/logs</code><br/>
# wandb: Agent Starting Run: kz3qrmjg with config:
# wandb: 	optimizer: AdamW
# wandb: wandb version 0.13.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#                     Syncing run <strong><a href="https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/runs/kz3qrmjg" target="_blank">autumn-sweep-2</a></strong> to <a href="https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/sweeps/o8rvmjks" target="_blank">https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/sweeps/o8rvmjks</a><br/>
# Start training..
# Epoch [1/100], Step [25/164],                         Loss: 0.9603, mIoU: 0.0277
# Epoch [1/100], Step [50/164],                         Loss: 0.9287, mIoU: 0.0485
# Epoch [1/100], Step [75/164],                         Loss: 0.9017, mIoU: 0.0719
# Epoch [1/100], Step [100/164],                         Loss: 0.8733, mIoU: 0.0913
# Epoch [1/100], Step [125/164],                         Loss: 0.8512, mIoU: 0.1063
# Epoch [1/100], Step [150/164],                         Loss: 0.8629, mIoU: 0.1185
# Start validation #1
# Validation Average Loss: 0.8431, Accuracy : 0.7965,                 mIoU: 0.205
# IoU by class : [{'Backgroud': 0.8416}, {'General trash': 0.14}, {'Paper': 0.5067}, {'Paper pack': 0.0003}, {'Metal': 0.0}, {'Glass': 0.002}, {'Plastic': 0.0391}, {'Styrofoam': 0.002}, {'Plastic bag': 0.7231}, {'Battery': 0.0}, {'Clothing': 0.0001}]
# trigger times: 0
# Best performance at epoch: 1
# Save model in ./saved
# Epoch [2/100], Step [25/164],                         Loss: 0.823, mIoU: 0.2072
# Epoch [2/100], Step [50/164],                         Loss: 0.8273, mIoU: 0.2063
# Epoch [2/100], Step [75/164],                         Loss: 0.8013, mIoU: 0.2103
# Epoch [2/100], Step [100/164],                         Loss: 0.8211, mIoU: 0.2142
# Epoch [2/100], Step [125/164],                         Loss: 0.7897, mIoU: 0.2196
# Epoch [2/100], Step [150/164],                         Loss: 0.7965, mIoU: 0.2238
# Start validation #2
# Validation Average Loss: 0.7926, Accuracy : 0.8549,                 mIoU: 0.2741
# IoU by class : [{'Backgroud': 0.8992}, {'General trash': 0.3221}, {'Paper': 0.639}, {'Paper pack': 0.0}, {'Metal': 0.0}, {'Glass': 0.0004}, {'Plastic': 0.2399}, {'Styrofoam': 0.1594}, {'Plastic bag': 0.7553}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 2
# Save model in ./saved
# Epoch [3/100], Step [25/164],                         Loss: 0.7479, mIoU: 0.2812
# Epoch [3/100], Step [50/164],                         Loss: 0.7797, mIoU: 0.2837
# Epoch [3/100], Step [75/164],                         Loss: 0.7541, mIoU: 0.2846
# Epoch [3/100], Step [100/164],                         Loss: 0.6865, mIoU: 0.2911
# Epoch [3/100], Step [125/164],                         Loss: 0.7191, mIoU: 0.2937
# Epoch [3/100], Step [150/164],                         Loss: 0.72, mIoU: 0.2953
# Start validation #3
# Validation Average Loss: 0.7433, Accuracy : 0.8843,                 mIoU: 0.316
# IoU by class : [{'Backgroud': 0.923}, {'General trash': 0.3223}, {'Paper': 0.6455}, {'Paper pack': 0.0004}, {'Metal': 0.0}, {'Glass': 0.0198}, {'Plastic': 0.3249}, {'Styrofoam': 0.4902}, {'Plastic bag': 0.7495}, {'Battery': 0.0}, {'Clothing': 0.0009}]
# trigger times: 0
# Best performance at epoch: 3
# Save model in ./saved
# Epoch [4/100], Step [25/164],                         Loss: 0.6505, mIoU: 0.335
# Epoch [4/100], Step [50/164],                         Loss: 0.6942, mIoU: 0.3362
# Epoch [4/100], Step [75/164],                         Loss: 0.6813, mIoU: 0.3363
# Epoch [4/100], Step [100/164],                         Loss: 0.6372, mIoU: 0.3403
# Epoch [4/100], Step [125/164],                         Loss: 0.7094, mIoU: 0.3426
# Epoch [4/100], Step [150/164],                         Loss: 0.6997, mIoU: 0.3449
# Start validation #4
# ...
# Epoch [38/100], Step [50/164],                         Loss: 0.3639, mIoU: 0.7073
# Epoch [38/100], Step [75/164],                         Loss: 0.437, mIoU: 0.71
# Epoch [38/100], Step [100/164],                         Loss: 0.4535, mIoU: 0.7072
# Epoch [38/100], Step [125/164],                         Loss: 0.4623, mIoU: 0.7057
# Epoch [38/100], Step [150/164],                         Loss: 0.4329, mIoU: 0.703
# Start validation #38
# Validation Average Loss: 0.6147, Accuracy : 0.9248,                 mIoU: 0.5089
# IoU by class : [{'Backgroud': 0.9509}, {'General trash': 0.445}, {'Paper': 0.766}, {'Paper pack': 0.5153}, {'Metal': 0.5065}, {'Glass': 0.4736}, {'Plastic': 0.4503}, {'Styrofoam': 0.6952}, {'Plastic bag': 0.7954}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 2
# Epoch [39/100], Step [25/164],                         Loss: 0.3345, mIoU: 0.7002
# Epoch [39/100], Step [50/164],                         Loss: 0.5621, mIoU: 0.7055
# Epoch [39/100], Step [75/164],                         Loss: 0.539, mIoU: 0.7069
# Epoch [39/100], Step [100/164],                         Loss: 0.4587, mIoU: 0.7033
# Epoch [39/100], Step [125/164],                         Loss: 0.4235, mIoU: 0.6997
# Epoch [39/100], Step [150/164],                         Loss: 0.4459, mIoU: 0.6997
# Start validation #39
# Validation Average Loss: 0.6172, Accuracy : 0.9268,                 mIoU: 0.5081
# IoU by class : [{'Backgroud': 0.951}, {'General trash': 0.4548}, {'Paper': 0.7698}, {'Paper pack': 0.4908}, {'Metal': 0.4776}, {'Glass': 0.4593}, {'Plastic': 0.4777}, {'Styrofoam': 0.7064}, {'Plastic bag': 0.8021}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 3
# Epoch [40/100], Step [25/164],                         Loss: 0.3331, mIoU: 0.694
# Epoch [40/100], Step [50/164],                         Loss: 0.5412, mIoU: 0.6968
# Epoch [40/100], Step [75/164],                         Loss: 0.4815, mIoU: 0.7025
# Epoch [40/100], Step [100/164],                         Loss: 0.4959, mIoU: 0.701
# Epoch [40/100], Step [125/164],                         Loss: 0.5238, mIoU: 0.702
# Epoch [40/100], Step [150/164],                         Loss: 0.6627, mIoU: 0.7025
# Start validation #40
# Validation Average Loss: 0.6175, Accuracy : 0.928,                 mIoU: 0.5155
# IoU by class : [{'Backgroud': 0.95}, {'General trash': 0.4596}, {'Paper': 0.7675}, {'Paper pack': 0.5014}, {'Metal': 0.4891}, {'Glass': 0.502}, {'Plastic': 0.478}, {'Styrofoam': 0.713}, {'Plastic bag': 0.8095}, {'Battery': 0.0}, {'Clothing': 0.0}]
# trigger times: 0
# Best performance at epoch: 40
# Save model in ./saved
# Epoch [41/100], Step [25/164],                         Loss: 0.4758, mIoU: 0.7184
# Epoch [41/100], Step [50/164],                         Loss: 0.3256, mIoU: 0.7167
# Epoch [41/100], Step [75/164],                         Loss: 0.5475, mIoU: 0.7099
# Epoch [41/100], Step [100/164],                         Loss: 0.4357, mIoU: 0.7099
# Epoch [41/100], Step [125/164],                         Loss: 0.4792, mIoU: 0.7069
# Epoch [41/100], Step [150/164],                         Loss: 0.3995, mIoU: 0.706
# Start validation #41
# Validation Average Loss: 0.6204, Accuracy : 0.9259,                 mIoU: 0.5073
# IoU by class : [{'Backgroud': 0.9505}, {'General trash': 0.4395}, {'Paper': 0.7533}, {'Paper pack': 0.4862}, {'Metal': 0.4903}, {'Glass': 0.4818}, {'Plastic': 0.4717}, {'Styrofoam': 0.6999}, {'Plastic bag': 0.8071}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 1
# Epoch [42/100], Step [25/164],                         Loss: 0.3358, mIoU: 0.7036
# Epoch [42/100], Step [50/164],                         Loss: 0.5426, mIoU: 0.6972
# Epoch [42/100], Step [75/164],                         Loss: 0.4203, mIoU: 0.6966
# Epoch [42/100], Step [100/164],                         Loss: 0.4109, mIoU: 0.6984
# Epoch [42/100], Step [125/164],                         Loss: 0.4922, mIoU: 0.701
# Epoch [42/100], Step [150/164],                         Loss: 0.5513, mIoU: 0.7025
# Start validation #42
# Validation Average Loss: 0.6163, Accuracy : 0.9265,                 mIoU: 0.5029
# IoU by class : [{'Backgroud': 0.9502}, {'General trash': 0.4545}, {'Paper': 0.7638}, {'Paper pack': 0.4634}, {'Metal': 0.4824}, {'Glass': 0.4428}, {'Plastic': 0.4682}, {'Styrofoam': 0.6922}, {'Plastic bag': 0.8145}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 2
# Epoch [43/100], Step [25/164],                         Loss: 0.3765, mIoU: 0.7016
# Epoch [43/100], Step [50/164],                         Loss: 0.3827, mIoU: 0.7112
# Epoch [43/100], Step [75/164],                         Loss: 0.4451, mIoU: 0.7086
# Epoch [43/100], Step [100/164],                         Loss: 0.4933, mIoU: 0.7076
# Epoch [43/100], Step [125/164],                         Loss: 0.5358, mIoU: 0.7066
# Epoch [43/100], Step [150/164],                         Loss: 0.5063, mIoU: 0.7072
# Start validation #43
# Validation Average Loss: 0.6221, Accuracy : 0.9255,                 mIoU: 0.4986
# IoU by class : [{'Backgroud': 0.9497}, {'General trash': 0.4505}, {'Paper': 0.7645}, {'Paper pack': 0.4511}, {'Metal': 0.4796}, {'Glass': 0.4218}, {'Plastic': 0.4715}, {'Styrofoam': 0.6913}, {'Plastic bag': 0.8046}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 3
# Epoch [44/100], Step [25/164],                         Loss: 0.4575, mIoU: 0.697
# Epoch [44/100], Step [50/164],                         Loss: 0.3737, mIoU: 0.7028
# Epoch [44/100], Step [75/164],                         Loss: 0.44, mIoU: 0.7032
# Epoch [44/100], Step [100/164],                         Loss: 0.5446, mIoU: 0.7029
# Epoch [44/100], Step [125/164],                         Loss: 0.4403, mIoU: 0.7044
# Epoch [44/100], Step [150/164],                         Loss: 0.4424, mIoU: 0.7039
# Start validation #44
# Validation Average Loss: 0.6187, Accuracy : 0.9266,                 mIoU: 0.5067
# IoU by class : [{'Backgroud': 0.9513}, {'General trash': 0.4594}, {'Paper': 0.7635}, {'Paper pack': 0.4797}, {'Metal': 0.4697}, {'Glass': 0.4823}, {'Plastic': 0.4654}, {'Styrofoam': 0.6959}, {'Plastic bag': 0.8065}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 4
# Epoch [45/100], Step [25/164],                         Loss: 0.41, mIoU: 0.6941
# Epoch [45/100], Step [50/164],                         Loss: 0.4663, mIoU: 0.6985
# Epoch [45/100], Step [75/164],                         Loss: 0.3195, mIoU: 0.7044
# Epoch [45/100], Step [100/164],                         Loss: 0.3688, mIoU: 0.7121
# Epoch [45/100], Step [125/164],                         Loss: 0.5135, mIoU: 0.7107
# Epoch [45/100], Step [150/164],                         Loss: 0.4381, mIoU: 0.7106
# Start validation #45
# Validation Average Loss: 0.6162, Accuracy : 0.9273,                 mIoU: 0.5081
# IoU by class : [{'Backgroud': 0.9512}, {'General trash': 0.4758}, {'Paper': 0.7662}, {'Paper pack': 0.4815}, {'Metal': 0.492}, {'Glass': 0.4506}, {'Plastic': 0.4651}, {'Styrofoam': 0.6983}, {'Plastic bag': 0.8082}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 5
# Epoch [46/100], Step [25/164],                         Loss: 0.4965, mIoU: 0.7125
# Epoch [46/100], Step [50/164],                         Loss: 0.4928, mIoU: 0.7142
# Epoch [46/100], Step [75/164],                         Loss: 0.4059, mIoU: 0.7127
# Epoch [46/100], Step [100/164],                         Loss: 0.4385, mIoU: 0.7091
# Epoch [46/100], Step [125/164],                         Loss: 0.5249, mIoU: 0.7088
# Epoch [46/100], Step [150/164],                         Loss: 0.5368, mIoU: 0.7093
# Start validation #46
# Validation Average Loss: 0.6195, Accuracy : 0.9277,                 mIoU: 0.5093
# IoU by class : [{'Backgroud': 0.951}, {'General trash': 0.4778}, {'Paper': 0.7664}, {'Paper pack': 0.4955}, {'Metal': 0.4724}, {'Glass': 0.4657}, {'Plastic': 0.4742}, {'Styrofoam': 0.6911}, {'Plastic bag': 0.808}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch 00046: reducing learning rate of group 0 to 9.0000e-06.
# Trigger Times: 6
# Epoch [47/100], Step [25/164],                         Loss: 0.4401, mIoU: 0.7187
# Epoch [47/100], Step [50/164],                         Loss: 0.454, mIoU: 0.7128
# Epoch [47/100], Step [75/164],                         Loss: 0.336, mIoU: 0.7122
# Epoch [47/100], Step [100/164],                         Loss: 0.4428, mIoU: 0.7131
# Epoch [47/100], Step [125/164],                         Loss: 0.5009, mIoU: 0.7124
# Epoch [47/100], Step [150/164],                         Loss: 0.4126, mIoU: 0.7111
# Start validation #47
# Validation Average Loss: 0.6214, Accuracy : 0.9272,                 mIoU: 0.507
# IoU by class : [{'Backgroud': 0.9504}, {'General trash': 0.4662}, {'Paper': 0.7642}, {'Paper pack': 0.487}, {'Metal': 0.4616}, {'Glass': 0.4769}, {'Plastic': 0.4675}, {'Styrofoam': 0.6945}, {'Plastic bag': 0.8087}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 7
# Epoch [48/100], Step [25/164],                         Loss: 0.4565, mIoU: 0.6932
# Epoch [48/100], Step [50/164],                         Loss: 0.3412, mIoU: 0.698
# Epoch [48/100], Step [75/164],                         Loss: 0.4368, mIoU: 0.701
# Epoch [48/100], Step [100/164],                         Loss: 0.4907, mIoU: 0.7029
# Epoch [48/100], Step [125/164],                         Loss: 0.5488, mIoU: 0.7055
# Epoch [48/100], Step [150/164],                         Loss: 0.5325, mIoU: 0.7084
# Start validation #48
# Validation Average Loss: 0.6228, Accuracy : 0.927,                 mIoU: 0.508
# IoU by class : [{'Backgroud': 0.9494}, {'General trash': 0.4626}, {'Paper': 0.7662}, {'Paper pack': 0.5148}, {'Metal': 0.4683}, {'Glass': 0.4765}, {'Plastic': 0.4524}, {'Styrofoam': 0.6899}, {'Plastic bag': 0.8075}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 8
# Epoch [49/100], Step [25/164],                         Loss: 0.499, mIoU: 0.6992
# Epoch [49/100], Step [50/164],                         Loss: 0.5139, mIoU: 0.7093
# Epoch [49/100], Step [75/164],                         Loss: 0.4563, mIoU: 0.7113
# Epoch [49/100], Step [100/164],                         Loss: 0.502, mIoU: 0.7145
# Epoch [49/100], Step [125/164],                         Loss: 0.599, mIoU: 0.7142
# Epoch [49/100], Step [150/164],                         Loss: 0.4285, mIoU: 0.7146
# Start validation #49
# Validation Average Loss: 0.6211, Accuracy : 0.9262,                 mIoU: 0.5054
# IoU by class : [{'Backgroud': 0.9508}, {'General trash': 0.4369}, {'Paper': 0.7579}, {'Paper pack': 0.5323}, {'Metal': 0.4727}, {'Glass': 0.4448}, {'Plastic': 0.4646}, {'Styrofoam': 0.6922}, {'Plastic bag': 0.8069}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 9
# Epoch [50/100], Step [25/164],                         Loss: 0.4876, mIoU: 0.7834
# Epoch [50/100], Step [50/164],                         Loss: 0.4354, mIoU: 0.7153
# Epoch [50/100], Step [75/164],                         Loss: 0.345, mIoU: 0.7144
# Epoch [50/100], Step [100/164],                         Loss: 0.5086, mIoU: 0.7113
# Epoch [50/100], Step [125/164],                         Loss: 0.601, mIoU: 0.7114
# Epoch [50/100], Step [150/164],                         Loss: 0.504, mIoU: 0.7137
# Start validation #50
# Validation Average Loss: 0.6177, Accuracy : 0.9275,                 mIoU: 0.5053
# IoU by class : [{'Backgroud': 0.951}, {'General trash': 0.4662}, {'Paper': 0.7674}, {'Paper pack': 0.4668}, {'Metal': 0.4626}, {'Glass': 0.4633}, {'Plastic': 0.467}, {'Styrofoam': 0.7042}, {'Plastic bag': 0.81}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 10
# Epoch [51/100], Step [25/164],                         Loss: 0.4153, mIoU: 0.7084
# Epoch [51/100], Step [50/164],                         Loss: 0.5147, mIoU: 0.7096
# Epoch [51/100], Step [75/164],                         Loss: 0.3332, mIoU: 0.7101
# Epoch [51/100], Step [100/164],                         Loss: 0.5008, mIoU: 0.713
# Epoch [51/100], Step [125/164],                         Loss: 0.5302, mIoU: 0.7152
# Epoch [51/100], Step [150/164],                         Loss: 0.4044, mIoU: 0.716
# Start validation #51
# Validation Average Loss: 0.6207, Accuracy : 0.9272,                 mIoU: 0.5055
# IoU by class : [{'Backgroud': 0.9496}, {'General trash': 0.4673}, {'Paper': 0.768}, {'Paper pack': 0.4744}, {'Metal': 0.4607}, {'Glass': 0.4538}, {'Plastic': 0.4766}, {'Styrofoam': 0.7003}, {'Plastic bag': 0.8101}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 11
# Epoch [52/100], Step [25/164],                         Loss: 0.4187, mIoU: 0.7164
# Epoch [52/100], Step [50/164],                         Loss: 0.5319, mIoU: 0.7189
# Epoch [52/100], Step [75/164],                         Loss: 0.4711, mIoU: 0.7234
# Epoch [52/100], Step [100/164],                         Loss: 0.4996, mIoU: 0.7175
# Epoch [52/100], Step [125/164],                         Loss: 0.3608, mIoU: 0.715
# Epoch [52/100], Step [150/164],                         Loss: 0.5561, mIoU: 0.7137
# Start validation #52
# Validation Average Loss: 0.6184, Accuracy : 0.9274,                 mIoU: 0.5097
# IoU by class : [{'Backgroud': 0.9498}, {'General trash': 0.4499}, {'Paper': 0.7666}, {'Paper pack': 0.5159}, {'Metal': 0.4715}, {'Glass': 0.4801}, {'Plastic': 0.467}, {'Styrofoam': 0.6941}, {'Plastic bag': 0.8113}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch 00052: reducing learning rate of group 0 to 2.7000e-06.
# Trigger Times: 12
# Epoch [53/100], Step [25/164],                         Loss: 0.5826, mIoU: 0.7168
# Epoch [53/100], Step [50/164],                         Loss: 0.4426, mIoU: 0.7208
# Epoch [53/100], Step [75/164],                         Loss: 0.4306, mIoU: 0.7209
# Epoch [53/100], Step [100/164],                         Loss: 0.4394, mIoU: 0.7191
# Epoch [53/100], Step [125/164],                         Loss: 0.5842, mIoU: 0.7183
# Epoch [53/100], Step [150/164],                         Loss: 0.4567, mIoU: 0.7158
# Start validation #53
# Validation Average Loss: 0.6189, Accuracy : 0.9272,                 mIoU: 0.5081
# IoU by class : [{'Backgroud': 0.9505}, {'General trash': 0.4569}, {'Paper': 0.7647}, {'Paper pack': 0.5083}, {'Metal': 0.449}, {'Glass': 0.4789}, {'Plastic': 0.4692}, {'Styrofoam': 0.7008}, {'Plastic bag': 0.8113}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Trigger Times: 13
# Early stopping!
# Start to test process.
# <br/>Waiting for W&B process to finish, PID 3060... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Charts/learning_rate</td><td>█████████████▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▁▁▁▁▁</td></tr><tr><td>Train/Accuracy</td><td>▁▆▇▇▇███████████████████████████████████</td></tr><tr><td>Train/Loss</td><td>█▇▆▅▅▄▂▄▄▃▃▄▅▂▅▁▅▂▃▂▃▃▄▁▂▂▄▁▂▄▂▄▁▁▄▁▃▃▄▂</td></tr><tr><td>Train/mIoU</td><td>▁▃▄▄▅▆▆▆▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>Val/Accuracy</td><td>▁▅▆▇▇▇▇█████████████████████████████████</td></tr><tr><td>Val/Loss</td><td>█▆▅▄▃▂▃▃▂▂▃▁▂▃▂▂▂▂▂▃▂▃▂▂▂▃▂▂▂▁▃▂▂▂▂▂▂▂▂▂</td></tr><tr><td>Val/mIoU</td><td>▁▂▃▅▆▇▇▆▇▇▇▇▇▇▇▇▇███████████████▇███████</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Charts/learning_rate</td><td>0.0</td></tr><tr><td>Train/Accuracy</td><td>0.9639</td></tr><tr><td>Train/Loss</td><td>0.4567</td></tr><tr><td>Train/mIoU</td><td>0.7158</td></tr><tr><td>Val/Accuracy</td><td>0.933</td></tr><tr><td>Val/Loss</td><td>0.6534</td></tr><tr><td>Val/mIoU</td><td>0.5114</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">ethereal-sweep-3</strong>: <a href="https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/runs/cm7ajtq5" target="_blank">https://wandb.ai/fullhouse/sweep_Unet%2B%2Beffv2/runs/cm7ajtq5</a><br/>
# Find logs at: <code>./wandb/run-20221222_155713-cm7ajtq5/logs</code><br/>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.

# %%
# best model 저장된 경로
model_path = os.path.join(saved_dir,model_names)

# best model 불러오기
model.load_state_dict(torch.load(model_path, map_location=device))

model = model.to(device)

# %%
def test(model, data_loader, device):
    size = 256
    transform = A.Compose([A.Resize(size, size)])
    print('Start prediction.')
    
    model.eval()
    
    file_name_list = []
    preds_array = np.empty((0, size*size), dtype=np.long)
    
    with torch.no_grad():
        for step, (imgs, image_infos) in enumerate(tqdm(test_loader)):
            
            # inference (512 x 512)
            outs = model(torch.stack(imgs).to(device))
            oms = torch.argmax(outs.squeeze(), dim=1).detach().cpu().numpy()
            
            # resize (256 x 256)
            temp_mask = []
            for img, mask in zip(np.stack(imgs), oms):
                transformed = transform(image=img, mask=mask)
                mask = transformed['mask']
                temp_mask.append(mask)
                
            oms = np.array(temp_mask)
            
            oms = oms.reshape([oms.shape[0], size*size]).astype(int)
            preds_array = np.vstack((preds_array, oms))
            
            file_name_list.append([i['file_name'] for i in image_infos])
    print("End prediction.")
    file_names = [y for x in file_name_list for y in x]
    
    return file_names, preds_array

# %%
# submission 파일이름
saved_csv = os.path.join('./submission',model_names[:-3]+".csv")
# sample_submisson.csv 열기
submission = pd.read_csv('./submission/sample_submission.csv', index_col=None)

# test set에 대한 prediction
file_names, preds = test(model, test_loader, device)

# PredictionString 대입
for file_name, string in zip(file_names, preds):
    submission = submission.append({"image_id" : file_name, "PredictionString" : ' '.join(str(e) for e in string.tolist())}, 
                                   ignore_index=True)

# submission.csv로 저장
submission.to_csv(saved_csv, index=False)
